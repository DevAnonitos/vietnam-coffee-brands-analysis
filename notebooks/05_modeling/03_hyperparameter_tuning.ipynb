# %% [markdown]
# # I. Project Information
# Notebook: 03 - Hyperparameter Tuning

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %% [markdown]
# ## III.B. Import Global Config

# %%
# Loading Global Config

def load_config(config_path="paths.yml"):
    with open(config_path, "r") as f:
        return yaml.safe_load(f)

config = load_config()

# %% [markdown]
# ## III.C. Import Dataset

# %% [markdown]
# # IV. Hyperparameter Tuning

# %% [markdown]
# ## IV.A.

# %% [markdown]
# ## IV.B.

# %% [markdown]
# ## IV.C.

# %% [markdown]
# ## IV.D.

# %% [markdown]
# # V. Export Result
