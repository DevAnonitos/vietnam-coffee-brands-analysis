# %% [markdown]
# # I. Project Information
# Notebook: 02 - Data Normalization

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ## III.B. Import Dataset

# %%
df = pd.read_csv("")

# %% [markdown]
# # IV. Data Normalization

# %% [markdown]
# # V. Export Dataset
