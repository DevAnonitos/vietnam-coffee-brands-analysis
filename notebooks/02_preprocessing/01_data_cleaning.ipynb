# %% [markdown]
# # I. Project Information
# Notebook: 01 - Data Cleaning

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %%
import yaml
import logging
import warnings
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.impute import SimpleImputer

# Python warning ignore
warnings.filterwarnings('ignore')

# Set pandas display options to show all columns and rows
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.float_format", lambda x: f"{x:,.3f}")

# Set numpy print options for better readability
np.set_printoptions(precision=3, suppress=True, linewidth=150)

# %% [markdown]
# ## III.B. Import Global Config

# %%
# Loading Global Config

PROJECT_ROOT = Path.cwd().parent

def load_config():
    config_path = PROJECT_ROOT / "configs" / "paths.yaml"
    with open(config_path, "r", encoding="utf-8") as f:
        return yaml.safe_load(f)

config = load_config()

# %% [markdown]
# ## III.C. Import Dataset

# %%
# Loading Dataset

df = pd.read_csv("")
df.head()

# %% [markdown]
# # IV. Data Cleaning

# %% [markdown]
# ## IV.A. Data Inspection

# %% [markdown]
# ### IV.A.1. Data Shape Inspection

# %%
# Data Shape Inspection

df.shape

# %% [markdown]
# ### IV.A.2. Data Info Inspection

# %%
# Data Info Inspection

df.info()

# %% [markdown]
# ## IV.B. Missing Values Inspection

# %%
# Missing Values Inspection

df.isnull()

# %%
# Missing Values Count

df.isnull().sum()

# %% [markdown]
# ## IV.C. Noisy Data Inspection

# %% [markdown]
# ## IV.D. Duplicated Values Inspection

# %%
# Data Duplicated Values Inspection

df.duplicated()

# %%
# Data Duplicated Values Count

df.duplicated().sum()

# %%
# Sum Of Duplicated Values

df.duplicated().sum()

# %% [markdown]
# ### IV.D.1. Removing Duplicates Data

# %%
# Remove Duplicated Values

df.drop_duplicates()

# %% [markdown]
# # V. Export Dataset

# %% [markdown]
# ## V.A. Export Dataset to CSV

# %%
# Export Dataset to CSV format

df.to_csv('', index=False)

# %% [markdown]
# ## V.B. Export Dataset to TSV

# %%
# Export Dataset to TSV format

df.to_csv('', sep="\t")

# %% [markdown]
# ## V.C. Export Dataset to Excel

# %%
# Export Dataset to Excel format

df.to_excel('', index=False)

# %% [markdown]
# ## V.D. Export Dataset to Json

# %%
# Export Dataset to Json format

df.to_json('', orient='records', lines=True)

# %% [markdown]
# ## V.E. Export Dataset to SQL

# %%
# Export Dataset to SQL format

df.to_sql()
