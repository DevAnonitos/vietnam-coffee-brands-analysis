# %% [markdown]
# # I. Project Information
# Notebook: 02 - Katinat Foods Menu

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %% [markdown]
# ## III.B. Import Dataset

# %% [markdown]
# # IV. Katinat Foods Menu

# %% [markdown]
# ## IV.A.

# %% [markdown]
# ## IV.B.

# %% [markdown]
# ## IV.C.

# %% [markdown]
# ## IV.C

# %% [markdown]
# # V. Export Dataset
