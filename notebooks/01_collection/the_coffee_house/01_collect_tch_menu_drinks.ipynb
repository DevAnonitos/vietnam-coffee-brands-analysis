# %% [markdown]
# # I. Project Information
# Notebook: 01 - The Coffee House Drinks Menu

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %% [markdown]
# ## III.B. Import Dataset

# %% [markdown]
# # IV. The Coffee House Drinks Menu

# %%
import numpy as np
import pandas as pd

# Set pandas display options to show all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## IV.A.

# %% [markdown]
# ## IV.B.

# %% [markdown]
# ## IV.C.

# %% [markdown]
# ## IV.D.

# %% [markdown]
# # V. Export Dataset
