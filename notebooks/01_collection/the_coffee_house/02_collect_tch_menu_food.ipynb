# %% [markdown]
# # I. Project Information
# Notebook: 02 - The Coffee House Foods Menu

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %% [markdown]
# ## III.B. Import Dataset

# %% [markdown]
# # IV. The Coffee House Foods Menu

# %% [markdown]
# ## IV.A.

# %% [markdown]
# ## IV.B.

# %% [markdown]
# ## IV.C.

# %% [markdown]
# ## IV.D

# %% [markdown]
# # V. Export Dataset
