# %% [markdown]
# # I. Project Information
# Notebook: 01 - Merge All Datasets

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %%
import os
import json
import yaml
import warnings
import numpy as np
import pandas as pd
from pathlib import Path
from datetime import datetime

# Python warning ignore
warnings.filterwarnings('ignore')

# Set pandas display options to show all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## III.B. Import Global Config

# %%
# Loading Global Config

PROJECT_ROOT = Path.cwd().parent

def load_config():
    config_path = PROJECT_ROOT / "configs" / "paths.yaml"
    with open(config_path, "r", encoding="utf-8") as f:
        return yaml.safe_load(f)

config = load_config()

# %% [markdown]
# ## III.C. Import Dataset

# %%
# Loading All Datasets

df = pd.read_csv("")

# %% [markdown]
# # IV. Merge All Datasets

# %% [markdown]
# ## IV.A.

# %% [markdown]
# ## IV.B.

# %% [markdown]
# ## IV.C.

# %% [markdown]
# # V. Export Dataset

# %% [markdown]
# ## V.A. Export Dataset to CSV

# %%
# Export Dataset to CSV format

df.to_csv('', index=False)

# %% [markdown]
# ## V.B. Export Dataset to TSV

# %%
# Export Dataset to TSV format

df.to_csv('', sep="\t")

# %% [markdown]
# ## V.C. Export Dataset to Excel

# %%
# Export Dataset to Excel format

df.to_excel('', index=False)

# %% [markdown]
# ## V.D. Export Dataset to Json

# %%
# Export Dataset to Json format

df.to_json('', orient='records', lines=True)

# %% [markdown]
# ## V.E. Export Dataset to Parquet

# %%
# Export Dataset to Parquet format

df.to_parquet('')

# %% [markdown]
# ## V.F. Export Dataset to Feather

# %%
# Export Dataset to Feather format

df.to_feather('')

# %% [markdown]
# ## V.G. Export Dataset to SQL

# %%
# Export Dataset to SQL format

df.to_sql('')
