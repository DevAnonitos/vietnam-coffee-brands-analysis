# %% [markdown]
# # I. Project Information
# Notebook: 01 - StarBucks Metadata

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %%
import yaml
import json
import warnings
import requests
import numpy as np
import pandas as pd
from pathlib import Path
from datetime import datetime
from bs4 import BeautifulSoup

# Python warning ignore
warnings.filterwarnings('ignore')

# Set pandas display options to show all columns and rows
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## III.B. Import Global Config

# %%
# Loading Global Config

PROJECT_ROOT = Path.cwd().parent

def load_config():
    config_path = PROJECT_ROOT / "configs" / "paths.yaml"
    with open(config_path, "r", encoding="utf-8") as f:
        return yaml.safe_load(f)

config = load_config()

# %% [markdown]
# ## III.C. Import URL

# %%
# Loading Url

url = "https://www.starbucks.vn"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}

# %% [markdown]
# # IV. StarBucks Metadata

# %% [markdown]
# ## IV.A.

# %%
def fetch_html(url: str) -> str:
    response = requests.get(url)
    response.raise_for_status()
    return response.text

html = fetch_html(url)
print(html)

# %% [markdown]
# ## IV.B.

# %%
def parse_html(html: str) -> BeautifulSoup:
    soup = BeautifulSoup(html, "html.parser")
    return soup

soup = parse_html(html)
print(soup.prettify())

# %% [markdown]
# ## IV.C.

# %% [markdown]
# ## IV.D.

# %% [markdown]
# # V. Export Dataset

# %% [markdown]
# ## V.A. Export Dataset to Json

# %%
# Export MetaData to Json Format

def export_to_json():
  return

# %% [markdown]
# ## V.B. Export Dataset to Yaml

# %%
# Export MetaData to Yaml Format

def export_to_yaml():
  return
