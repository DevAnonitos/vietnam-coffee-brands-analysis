# %% [markdown]
# # I. Project Information
# Notebook: 02 - Cong Caphe Foods Menu

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %%
import numpy as np
import pandas as pd

# Set pandas display options to show all columns and rows
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## III.B. Import URL

# %%
# Loading Url

# %% [markdown]
# # IV. Cong Caphe Foods Menu

# %% [markdown]
# ## IV.A.

# %% [markdown]
# ## IV.B.

# %% [markdown]
# ## IV.C.

# %% [markdown]
# ## IV.D.

# %% [markdown]
# # V. Export Dataset

# %% [markdown]
# ## V.A. Export Dataset to CSV

# %%
df.to_csv('', index=False)
