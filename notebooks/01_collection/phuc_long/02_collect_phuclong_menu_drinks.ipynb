# %% [markdown]
# # I. Project Information
# Notebook: 02 - Phuc Long Drinks Menu

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %%
import warnings
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# Python warning ignore
warnings.filterwarnings('ignore')

# Set pandas display options to show all columns and rows
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## III.B. Import Global Config

# %%
# Loading Global Config

PROJECT_ROOT = Path.cwd().parent

def load_config():
    config_path = PROJECT_ROOT / "configs" / "paths.yaml"
    with open(config_path, "r", encoding="utf-8") as f:
        return yaml.safe_load(f)

config = load_config()

# %% [markdown]
# ## III.B. Import URL

# %%
# Loading Url

url = "https://phuclong.com.vn"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}
# Out:
# Bad pipe message: %s [b' 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Sa']
# Bad pipe message: %s [b'ri/537.36\r\nAccept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/', b'ng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7\r\nAccept-Encoding: gzip, deflate, br, zstd\r\nA']
# Bad pipe message: %s [b'ept-Language: en-US,en;q=0.9\r\nPriority: u=0, i\r\nReferer: https://idx.google.com/\r\nSec-Ch-Ua: "Chro', b'um";v="143", "Not A(Brand";v="24", "Google Chrome";v="143"\r\nSec-Ch-Ua-Arch: "x86"\r\nSec-Ch-Ua-Bitness: "64"\r\n', b'c-Ch-Ua-Form-Factors: "Desktop"\r\nSec-Ch-Ua-Full-Version: "143.0.7499.147"\r\nSec-Ch-', b'-Full-Version-List: "Chromium";v="143.0.7499.147", "Not A(Brand";v="24.0.0.0", "Goog', b' Chrome";v="143.0.7499.147"\r\nSec-Ch-Ua-Mobile: ?0\r\nSec-Ch-Ua-Model: ""\r\nSec-Ch-Ua-Platform: "Windows"\r\nSec-', b'-Ua-Platform-Version: "19.0.0"\r\nSec-Ch-Ua-Wow64: ?0\r\nSec-Fetch-Des']
# Bad pipe message: %s [b' iframe\r\nSec-Fetch-Mode: navigate\r\nSec-Fetch-Site: cross-site\r\nSec-Fetch-Storage-Access: active\r\nSec-Fetch-User: ?1']
# Bad pipe message: %s [b'Sec-User-Ip:']
# Bad pipe message: %s [b'0.20.20.207\r\nUpgrade-Insecure-R', b'uests: 1\r\nX-Forwarded-Host: 45155-firebase-data-science-1761325109706.cluster-isls3qj2gbd5qs4jkjqvha', b'v6.cloudworkstations.dev\r\nX-Goog-Workstations-Endpoint: workstations-71af9a5f-da96-49e5-b303-cfa18c0abf']
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 663, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 663, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 663, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 663, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 663, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 663, in shell_channel_thread_main
#     _, msg2 = self.session.feed_identities(msg, copy=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/data-science/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list

# %% [markdown]
# # IV. Phuc Long Drinks Menu

# %% [markdown]
# ## IV.A.

# %% [markdown]
# ## IV.B.

# %% [markdown]
# ## IV.C.

# %% [markdown]
# ## IV.D.

# %% [markdown]
# # V. Export Dataset

# %% [markdown]
# ## V.A. Export Dataset to CSV

# %%
df.to_csv('', index=False)
