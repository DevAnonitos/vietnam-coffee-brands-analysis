# %% [markdown]
# # I. Project Information
# Notebook: 04 - Time Series Visualization

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %% [markdown]
# ## III.B. Import Dataset

# %% [markdown]
# # IV. Time Series Visualization

# %% [markdown]
# ## IV.A.

# %% [markdown]
# ## IV.B.

# %% [markdown]
# ## IV.C.

# %% [markdown]
# ## IV.D.

# %% [markdown]
# # V. Export Figure
