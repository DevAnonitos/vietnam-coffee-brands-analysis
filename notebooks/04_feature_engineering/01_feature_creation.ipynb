# %% [markdown]
# # I. Project Information
# Notebook: 01 - Features Creation

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %% [markdown]
# ## III.B. Import Global Config

# %% [markdown]
# ## III.C. Import Dataset

# %% [markdown]
# # IV. Features Creation

# %% [markdown]
# # V. Export Dataset
