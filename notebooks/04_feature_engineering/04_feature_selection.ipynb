# %% [markdown]
# # I. Project Information
# Notebook: 04 - Features Extraction

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %% [markdown]
# ## III.B. Import Global Config

# %% [markdown]
# ## III.C. Import Dataset

# %% [markdown]
# # IV. Features Selection

# %% [markdown]
# # V. Export Dataset
