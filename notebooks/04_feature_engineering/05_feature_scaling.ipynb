# %% [markdown]
# # I. Project Information
# Notebook: 05 - Feature Scaling

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %%
import numpy as np
import pandas as pd

# Set pandas display options to show all columns and rows
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## III.B. Import Global Config

# %%
# Loading Global Config

def load_config(config_path="paths.yml"):
    with open(config_path, "r") as f:
        return yaml.safe_load(f)

config = load_config()

# %% [markdown]
# ## III.C. Import Dataset

# %%
# Loading Dataset
df = pd.read_csv("")
df.head()

# %% [markdown]
# # IV. Feature Scaling

# %% [markdown]
# ## IV.A.

# %% [markdown]
# ## IV.B.

# %% [markdown]
# ## IV.C.

# %% [markdown]
# ## IV.D.

# %% [markdown]
# # V. Export Dataset

# %% [markdown]
# ## V.A. Export Dataset to CSV

# %%
# Export Dataset to CSV format
df.to_csv('', index=False)

# %% [markdown]
# ## V.A. Export Dataset to TSV

# %%
# Export Dataset to TSV format
df.to_csv('', sep="\t")

# %% [markdown]
# ## V.A. Export Dataset to Excel

# %%
# Export Dataset to Excel format
df.to_excel('', index=False)

# %% [markdown]
# ## V.D. Export Dataset to Json

# %%
# Export Dataset to Json format
df.to_json('', orient='records', lines=True)

# %% [markdown]
# ## V.E. Export Dataset to SQL

# %%
# Export Dataset to SQL format
df.to_sql()
