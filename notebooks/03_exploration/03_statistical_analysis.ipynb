# %% [markdown]
# # I. Project Information
# Notebook: 03 - Statistical Analysis

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %%
import numpy as np
import pandas as pd
from scipy import stats

# Set pandas display options to show all columns and rows
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.float_format", lambda x: f"{x:,.3f}")

# %% [markdown]
# ## III.B. Import Dataset

# %%
df = pd.read_csv("../data/processed/")
df.head()

# %% [markdown]
# # IV. Statistical Analysis

# %% [markdown]
# ## IV.A. Descriptive Statistics

# %%
# summary statistical
df.describe(include="all")

# %% [markdown]
# ## IV.B. Distribution Analysis

# %% [markdown]
# ### IV.B.1. Skewness Analysis

# %%
# Skewness Analysis
df.skew()

# %% [markdown]
# ### IV.B.2. Kurtosis Analysis

# %%
# Kurtosis Analysis
df.kurt()
# Out:
# Bad pipe message: %s [b' 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Sa']
# Bad pipe message: %s [b'ri/537.36\r\nAccept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/', b'ng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7\r\nAccept-Encoding: gzip, deflate, br, zstd\r\nA']
# Bad pipe message: %s [b'ept-Language: en-US,en;q=0.9,vi;q=0.8\r\nPriority: u=0, i\r\nReferer: https://idx.google.com/\r\nSec-Ch-', b': "Chromium";v="142", "Google Chrome";v="142", "Not_A Brand";v="99"\r\nSec-Ch-Ua-Arch:', b'x86"\r\nSec-Ch-Ua-Bitness: "64"\r\n']
# Bad pipe message: %s [b'c-Ch-Ua-Form-Factors: "Desktop"\r\nSec-Ch-Ua-Full-Version: "142.0.7444.176"\r\nSec-Ch-', b'-Full-Version-List: "Chromium";v="142.0.7444.176", "Google Chrome";v="142.0.7444.176', b' "Not_A Brand";v="99.0.0.0"\r\nSec-']
# Bad pipe message: %s [b'-Ua-Mobile: ?0\r\nSec-Ch-Ua-Model: ""\r\nSec-Ch-Ua-Platform: "Windows"']
# Bad pipe message: %s [b'Sec-Ch-Ua-Pl']
# ...

# %% [markdown]
# ## IV.C. Dispersion Analysis

# %% [markdown]
# ## IV.D. Group-Based Statistical Analysis

# %% [markdown]
# # V. Export Result
