# %% [markdown]
# # I. Project Information
# Notebook: 01 - Data Overview

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %%
import yaml
import warnings
import numpy as np
import pandas as pd
from pathlib import Path

# Python warning ignore
warnings.filterwarnings('ignore')

# Set pandas display options to show all columns and rows
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## III.B. Import Global Config

# %%
# Loading Global Config

PROJECT_ROOT = Path.cwd().parent

def load_config():
    config_path = PROJECT_ROOT / "configs" / "paths.yaml"
    with open(config_path, "r", encoding="utf-8") as f:
        return yaml.safe_load(f)

config = load_config()

# %% [markdown]
# ## III.C. Import Dataset

# %%
# Loading Dataset

df = pd.read_csv("../data/processed/")
df.head()

# %% [markdown]
# # IV. Data Overview

# %% [markdown]
# ## IV.A. Data Inspection

# %% [markdown]
# ### IV.A.1. Data Shape Inspection

# %%
# Data Shape Inspection

df.shape

# %% [markdown]
# ### IV.A.2. Data Information Inspection

# %%
# Data Information Inspection

df.info()

# %% [markdown]
# ### IV.A.3. Data Sample Inspection

# %%
# Data Sample Inspection

df.sample()

# %% [markdown]
# ### IV.A.4. Data Columns Inspection

# %%
# Data Columns Inspection

df.columns

# %% [markdown]
# ### IV.A.5. Data Head & Tail Inspection

# %%
# Data Head Inspection

df.head()

# %%
# Data Tail Inspection

df.tail()

# %% [markdown]
# ### IV.A.6. Data Types & Memory Usage Inspection

# %%
# Data Types Inspection

df.dtypes

# %%
# Data Memory Usage

df.memory_usage()

# %% [markdown]
# ## IV.B. Data Structure Inspection

# %% [markdown]
# ### IV.B.1. Data Columns Inspection

# %%
# Check list for column

df.columns.tolist()

# %% [markdown]
# ### IV.B.2. Data Types Inspection

# %%
# Numeric columns
numeric_cols = df.select_dtypes(include=['int', 'int32', 'int64', 'float', 'float32', 'float64']).columns

# Boolean columns
boolean_cols = df.select_dtypes(include=['bool']).columns

# String columns
string_cols = df.select_dtypes(include=['string']).columns

# Categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns

# Datatime columns
datetime_cols = df.select_dtypes(include=['datetime64', 'datetime64[ns]', 'datetimetz']).columns

# %% [markdown]
# ### IV.B.3. Data Cardinality Inspection

# %%
# Data Cardinality Inspection

df.nunique()

# %%
# Numberic Columns Cardinality

df[numeric_cols].nunique()

# %%
# Boolean Columns Cardinality

df[boolean_cols].nunique()

# %%
# String Columns Cardinality

df[string_cols].nunique()

# %%
# Categorical Columns Cardinality

df[categorical_cols].nunique()

# %%
# Datetime Columns Cardinality

df[datetime_cols].nunique()

# %% [markdown]
# ## IV.C. Data Quality Inspection

# %%
# Data Quality Inspection

# %% [markdown]
# ## IV.D. Data Integrity Validation

# %%
# Data Integrity Validation

# %% [markdown]
# ## IV.E. Data Statistical Summary

# %%
# Summary Describe Values

df.describe(include="all")

# %% [markdown]
# # V. Export Dataset
