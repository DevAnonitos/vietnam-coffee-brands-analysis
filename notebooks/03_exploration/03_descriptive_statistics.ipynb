# %% [markdown]
# # I. Project Information
# Notebook: 03 - Statistical Analysis

# %% [markdown]
# # II. Notebook Objectives

# %% [markdown]
# # III. Notebook Setup

# %% [markdown]
# ## III.A. Import Libraries

# %%
import numpy as np
import pandas as pd
from scipy import stats

# Set pandas display options to show all columns and rows
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.float_format", lambda x: f"{x:,.3f}")

# %% [markdown]
# ## III.B. Import Global Config

# %% [markdown]
# ## III.C. Import Dataset

# %%
# Loading Dataset
df = pd.read_csv("../data/processed/")
df.head()

# %% [markdown]
# # IV. Descriptive Statistics

# %% [markdown]
# ## IV.A. Measures of Central Tendency

# %%
# summary statistical
df.describe(include="all")

# %% [markdown]
# ### IV.A.1. Mean

# %%
# Mean
df.mean()

# %% [markdown]
# ### IV.A.2. Median

# %%
# Median
df.median()

# %% [markdown]
# ### IV.A.3. Mode

# %%
# Mode
df.mode()

# %% [markdown]
# ## IV.B. Measures of Dispersion

# %% [markdown]
# ### IV.B.1. Range

# %%
# Range
df.max() - df.min()

# %% [markdown]
# ### IV.B.2. Variance

# %%
# Variance
df.var()

# %% [markdown]
# ### IV.B.3. Standard Deviation

# %%
df.std()

# %% [markdown]
# ### IV.B.4. Interquartile Range

# %%
df.quantile(0.75) - df.quantile(0.25)

# %% [markdown]
# ## IV.C. Distribution Shape

# %% [markdown]
# ### IV.C.1. Skewness

# %%
# Skewness
df.skew()

# %% [markdown]
# ### IV.C.2. Kurtosis

# %%
# Kurtosis
df.kurt()

# %% [markdown]
# ### IV.C.3. Percentiles

# %% [markdown]
# ## IV.D. Frequency Analysis

# %% [markdown]
# ## IV.E. Group-Based Analysis

# %% [markdown]
# # V. Export Result

# %% [markdown]
# ## V.A. Export Result to Latex
